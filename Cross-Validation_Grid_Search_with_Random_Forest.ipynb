# %% [markdown]
# **Run the following two cells before you begin.**

# %%
# %autosave 10
# Out:
# Autosaving every 10 seconds

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
df=pd.read_csv('C:/Users/HP/Desktop/Datascience/Data_Exploration_and_Cleaning/cleaned_data.csv')

# %% [markdown]
# **Run the following 3 cells to create a list of features, create a train/test split, and instantiate a random forest classifier.**

# %%
features_response = df.columns.tolist()
items_to_remove = ['ID', 'SEX', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6',
                   'EDUCATION_CAT', 'graduate school', 'high school', 'none',
                   'others', 'university']
features_response = [item for item in features_response if item not in items_to_remove]
features_response
# Out:
# ['LIMIT_BAL',
#  'EDUCATION',
#  'MARRIAGE',
#  'AGE',
#  'PAY_1',
#  'BILL_AMT1',
#  'BILL_AMT2',
#  'BILL_AMT3',
#  'BILL_AMT4',
#  'BILL_AMT5',
#  'BILL_AMT6',
#  'PAY_AMT1',
#  'PAY_AMT2',
#  'PAY_AMT3',
#  'PAY_AMT4',
#  'PAY_AMT5',
#  'PAY_AMT6',
#  'default payment next month']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df[features_response[:-1]].values,
    df['default payment next month'].values,
    test_size=0.2, random_state=24
)

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=10, criterion='gini', max_depth=3,
    min_samples_split=2, min_samples_leaf=1, min_weight_fraction_leaf=0.0,
    max_features='auto', max_leaf_nodes=None, min_impurity_decrease=0.0,
    min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=None,
    random_state=4, verbose=0, warm_start=False, class_weight=None
)

# %% [markdown]
# **Create a dictionary representing the grid for the `max_depth` and `n_estimators` hyperparameters that will be searched. Include depths of 3, 6, 9, and 12, and 10, 50, 100, and 200 trees.**

# %%
param={
    'max_depth':[3,6,9,12],
     'n_estimators':[10,50,100,200]
    }

# %% [markdown]
# ________________________________________________________________
# **Instantiate a `GridSearchCV` object using the same options that we have previously in this course, but with the dictionary of hyperparameters created above. Set `verbose=2` to see the output for each fit performed.**

# %%
from sklearn.model_selection import GridSearchCV
cv = GridSearchCV(rf, param_grid=param, scoring='roc_auc',
                        n_jobs=None, iid=False, refit=True, cv=4, verbose=2,
                        pre_dispatch=None, error_score=np.nan, return_train_score=True)

# %% [markdown]
# ____________________________________________________
# **Fit the `GridSearchCV` object on the training data.**

# %%
cv.fit(X_train,y_train)
# Out:
# Fitting 4 folds for each of 16 candidates, totalling 64 fits
# [CV] max_depth=3, n_estimators=10 ....................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] ..................... max_depth=3, n_estimators=10, total=   0.8s
# [CV] max_depth=3, n_estimators=10 ....................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.7s remaining:    0.0s
# [CV] ..................... max_depth=3, n_estimators=10, total=   0.4s
# [CV] max_depth=3, n_estimators=10 ....................................
# [CV] ..................... max_depth=3, n_estimators=10, total=   0.3s
# [CV] max_depth=3, n_estimators=10 ....................................
# [CV] ..................... max_depth=3, n_estimators=10, total=   0.4s
# [CV] max_depth=3, n_estimators=50 ....................................
# [CV] ..................... max_depth=3, n_estimators=50, total=   1.7s
# ...

# %% [markdown]
# ___________________________________________________________
# **Put the results of the grid search in a pandas DataFrame.**

# %%
pandas=pd.DataFrame(cv.cv_results_)
pandas
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.412705      0.108620         0.057277        0.068389
# 1        1.403856      0.172927         0.054030        0.018072
# 2        2.977647      0.255768         0.090661        0.015456
# 3        5.308593      0.309247         0.198415        0.046414
# 4        0.518774      0.063257         0.016159        0.000909
# 5        2.398583      0.093896         0.079065        0.030965
# 6        4.935288      0.552881         0.119669        0.011479
# 7        9.541804      0.415953         0.275097        0.046356
# 8        0.838875      0.118913         0.024131        0.005754
# 9        3.409384      0.469707         0.105330        0.049952
# 10       6.187333      0.526473         0.163335        0.031658
# 11      12.782214      0.678749         0.327514        0.018609
# 12       0.805051      0.023404         0.026993        0.001730
# ...

# %% [markdown]
# **Find the best hyperparameters from the cross-validation.**

# %%
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(6, 3))
axs[0].plot(pandas['param_n_estimators'],
            pandas['mean_fit_time'],
            '-o')
axs[0].set_xlabel('Number of trees')
axs[0].set_ylabel('Mean fit time (seconds)')
axs[1].errorbar(pandas['param_n_estimators'],
                pandas['mean_test_score'],
                yerr=pandas['std_test_score'])
axs[1].set_xlabel('Number of trees')
axs[1].set_ylabel('Mean testing ROC AUC $\pm$ 1 SD ')
plt.tight_layout()

# %% [markdown]
# ________________________________________________________________________________________________________
# **Create a `pcolormesh` visualization of the mean testing score for each combination of hyperparameters.**
#
# <details>
#     <summary>Hint:</summary>
#     Remember to reshape the values of the mean testing scores to be a two-dimensional 4x4 grid.
# </details>

# %%
# Create a 5x5 grid
ax = plt.axes()
ax.errorbar(pandas['param_max_depth'],
            pandas['mean_train_score'],
            yerr=pandas['std_train_score'],
            label='Mean $\pm$ 1 SD training scores')
ax.errorbar(pandas['param_max_depth'],
            pandas['mean_test_score'],
            yerr=pandas['std_test_score'],
            label='Mean $\pm$ 1 SD testing scores')
ax.legend()
plt.xlabel('max_depth')
plt.ylabel('ROC AUC')
# Out:
# Text(0, 0.5, 'ROC AUC')

# %%
# Set color map to `plt.cm.jet`
xx, yy = np.meshgrid(range(5), range(5))

# %%
cv.best_params_
# Out:
# {'max_depth': 9, 'n_estimators': 200}

# %%
mean_test_score = pandas['mean_test_score'].values.reshape(4,4)
mean_test_score
# Out:
# array([[0.75730766, 0.76365051, 0.76281941, 0.76247114],
#        [0.7664656 , 0.77314378, 0.77355231, 0.77359992],
#        [0.76716589, 0.77383029, 0.77496884, 0.77619851],
#        [0.75722825, 0.77157003, 0.77381473, 0.77549938]])

# %%
# Visualize pcolormesh
ax = plt.axes()
pcolor_ex = ax.pcolormesh(xx, yy, mean_test_score, cmap=plt.cm.jet)
plt.colorbar(pcolor_ex, label='Color scale')
ax.set_xlabel('X coordinate')
ax.set_ylabel('Y coordinate')
# Out:
# Text(0, 0.5, 'Y coordinate')

# %% [markdown]
# ________________________________________________________________________________________________________
# **Conclude which set of hyperparameters to use.**

# %%
# Create a dataframe of the feature names and importance
feat_imp_df = pd.DataFrame({'Features': features_response[:-1], 'Importance': cv.best_estimator_.feature_importances_})
feat_imp_df
# Out:
#      Features  Importance
# 0   LIMIT_BAL    0.059961
# 1   EDUCATION    0.007545
# 2    MARRIAGE    0.004504
# 3         AGE    0.026774
# 4       PAY_1    0.437439
# 5   BILL_AMT1    0.042195
# 6   BILL_AMT2    0.041562
# 7   BILL_AMT3    0.037268
# 8   BILL_AMT4    0.034123
# 9   BILL_AMT5    0.032413
# 10  BILL_AMT6    0.033839
# 11   PAY_AMT1    0.059434
# 12   PAY_AMT2    0.045518
# 13   PAY_AMT3    0.043299
# 14   PAY_AMT4    0.034321
# 15   PAY_AMT5    0.030734
# 16   PAY_AMT6    0.029070

# %%
# Sort values by importance
feat_imp_df.sort_values('Importance', ascending = False)
# Out:
#      Features  Importance
# 4       PAY_1    0.437439
# 0   LIMIT_BAL    0.059961
# 11   PAY_AMT1    0.059434
# 12   PAY_AMT2    0.045518
# 13   PAY_AMT3    0.043299
# 5   BILL_AMT1    0.042195
# 6   BILL_AMT2    0.041562
# 7   BILL_AMT3    0.037268
# 14   PAY_AMT4    0.034321
# 8   BILL_AMT4    0.034123
# 10  BILL_AMT6    0.033839
# 9   BILL_AMT5    0.032413
# 15   PAY_AMT5    0.030734
# 16   PAY_AMT6    0.029070
# 3         AGE    0.026774
# 1   EDUCATION    0.007545
# 2    MARRIAGE    0.004504
